# %%
import os
import numpy as np

# %%
list_path = os.listdir()

# %%
list_path
# Out:
# ['HongLuoNelsonJOC2015.pdf',
#  'HongLiuMS2009.pdf',
#  'JiangHongNelsonJOC2020.pdf',
#  'HongLiLuoNRL2020.pdf',
#  'XuNelsonHongJOC2013.pdf',
#  'ShenHongZhangIJOC2021.pdf',
#  'HongJunejaLiuOR2017.pdf',
#  '.DS_Store',
#  'ZhangHongZhangAOR2012.pdf',
#  'YunHongJiangWangNRL2019.pdf',
#  'ChangHongWanJOC2013.pdf',
#  'HongJiangJORSOC2017.pdf',
#  'PichNelsonHongEJOR2006.pdf',
#  'HongNRL2006.pdf',
#  'JiangNelsonHongIISE2022.pdf',
#  'FanHongNelsonOR2016.pdf',
#  'HongHuLiuTOMACS2014.pdf',
#  'LiuHongORL2009.pdf',
#  'HongYangZhangOR2011.pdf',
#  'LiuHongOR2011.pdf',
#  'HongNelsonTOMACS2007.pdf',
#  'FuHongHuMS2009.pdf',
#  'HongJunejaLuoJOC2014.pdf',
#  'SunHongORL2010.pdf',
#  'HongHuangLamMS2021.pdf',
#  'LiuHongNRL2009.pdf',
#  'HongLiuOR2010.pdf',
#  'SunHongHuOR2014.pdf',
#  'HongOR2009.pdf',
#  'HongNelsonOR2006.pdf',
#  'LuoHongNelsonWuOR2015.pdf',
#  'HongHuZhangJOC2014.pdf',
#  'rename_gene_md.ipynb',
#  'FanHongZhangMS2020.pdf',
#  'HongJiangAPJOR2019.pdf',
# ...

# %%
for file in list_path:
    if ".pdf" in file:
        name = file.split(".")[0][:-4]
        year = file.split(".")[0][-4:]
        new_name = year+"_"+name+".pdf"
        print(new_name)
        os.rename(file, new_name)
        
# 已经成功修改了名字
# Out:
# 2015_HongLuoNelsonJOC.pdf
# 2009_HongLiuMS.pdf
# 2020_JiangHongNelsonJOC.pdf
# 2020_HongLiLuoNRL.pdf
# 2013_XuNelsonHongJOC.pdf
# 2021_ShenHongZhangIJOC.pdf
# 2017_HongJunejaLiuOR.pdf
# 2012_ZhangHongZhangAOR.pdf
# 2019_YunHongJiangWangNRL.pdf
# 2013_ChangHongWanJOC.pdf
# 2017_HongJiangJORSOC.pdf
# 2006_PichNelsonHongEJOR.pdf
# 2006_HongNRL.pdf
# 2022_JiangNelsonHongIISE.pdf
# 2016_FanHongNelsonOR.pdf
# 2014_HongHuLiuTOMACS.pdf
# 2009_LiuHongORL.pdf
# 2011_HongYangZhangOR.pdf
# 2011_LiuHongOR.pdf
# 2007_HongNelsonTOMACS.pdf
# 2009_FuHongHuMS.pdf
# 2014_HongJunejaLuoJOC.pdf
# 2010_SunHongORL.pdf
# 2021_HongHuangLamMS.pdf
# 2009_LiuHongNRL.pdf
# 2010_HongLiuOR.pdf
# 2014_SunHongHuOR.pdf
# 2009_HongOR.pdf
# 2006_HongNelsonOR.pdf
# 2015_LuoHongNelsonWuOR.pdf
# 2014_HongHuZhangJOC.pdf
# 2020_FanHongZhangMS.pdf
# 2019_HongJiangAPJOR.pdf
# 2022_ZhangZhangZhangWangLuHongTIST.pdf
# 2013_HuHongZhangIIE.pdf
# 2018_ShenHongZhangIISE.pdf
# 2021_HongZhangTutOrials.pdf
# ...

# %%
list_path = os.listdir()

# %%
list_path
# Out:
# ['2009_LiuHongORL.pdf',
#  '2014_HongHuLiuTOMACS.pdf',
#  '2012_ZhangHongZhangAOR.pdf',
#  '2010_SunHongORL.pdf',
#  '2013_HuHongZhangIIE.pdf',
#  '.DS_Store',
#  '2021_HongHuangLamMS.pdf',
#  '2021_ShenHongZhangIJOC.pdf',
#  '2015_HongXuZhangEJOR.pdf',
#  '2020_FanHongZhangMS.pdf',
#  '2021_HongZhangTutOrials.pdf',
#  '2018_FangHongIISE.pdf',
#  '2011_HongYangZhangOR.pdf',
#  '2010_HongNelsonXuORL.pdf',
#  '2011_LiuHongOR.pdf',
#  '2009_HongLiuMS.pdf',
#  '2015_HongLuoNelsonJOC.pdf',
#  '2009_LiuHongNRL.pdf',
#  '2018_ShenHongZhangIISE.pdf',
#  '2013_ChangHongWanJOC.pdf',
#  '2013_XuNelsonHongJOC.pdf',
#  '2006_HongNRL.pdf',
#  '2006_PichNelsonHongEJOR.pdf',
#  '2017_HongJunejaLiuOR.pdf',
#  '2007_HongNelsonTOMACS.pdf',
#  '2021_ZhongHongLiuPOM.pdf',
#  '2019_HongJiangAPJOR.pdf',
#  '2014_HongJunejaLuoJOC.pdf',
#  '2007_HongNelsonIIE.pdf',
#  '2014_SunHongHuOR.pdf',
#  '2014_HongHuZhangJOC.pdf',
#  '2022_ZhongHongOR.pdf',
#  'rename_gene_md.ipynb',
#  '2020_JiangHongNelsonJOC.pdf',
# ...

# %%
import copy

# %%
len(list_path)
# Out:
# 50

# %%
useful_list = [file  for file in list_path if file.find(".pdf") > 0]

# %%
good_list = [useful_list[i] for i in np.argsort([-int(file.split(".")[0][:4]) for file in useful_list])]

# %%
good_list
# Out:
# ['2022_ZhongHongOR.pdf',
#  '2022_ZhangZhangZhangWangLuHongTIST.pdf',
#  '2022_JiangNelsonHongIISE.pdf',
#  '2021_HongFanLuoFEM.pdf',
#  '2021_HongZhangTutOrials.pdf',
#  '2021_ShenHongZhangIJOC.pdf',
#  '2021_ZhongHongLiuPOM.pdf',
#  '2021_HongHuangLamMS.pdf',
#  '2020_FanHongZhangMS.pdf',
#  '2020_JiangHongNelsonJOC.pdf',
#  '2020_HongLiLuoNRL.pdf',
#  '2019_HongJiangAPJOR.pdf',
#  '2019_YunHongJiangWangNRL.pdf',
#  '2018_FangHongIISE.pdf',
#  '2018_ShenHongZhangIISE.pdf',
#  '2017_HongJiangJORSOC.pdf',
#  '2017_HongJunejaLiuOR.pdf',
#  '2016_FanHongNelsonOR.pdf',
#  '2015_HongXuZhangEJOR.pdf',
#  '2015_LuoHongNelsonWuOR.pdf',
#  '2015_HongLuoNelsonJOC.pdf',
#  '2014_HongJunejaLuoJOC.pdf',
#  '2014_HongHuLiuTOMACS.pdf',
#  '2014_SunHongHuOR.pdf',
#  '2014_HongHuZhangJOC.pdf',
#  '2013_ChangHongWanJOC.pdf',
#  '2013_XuNelsonHongJOC.pdf',
#  '2013_HuHongZhangIIE.pdf',
#  '2012_ZhangHongZhangAOR.pdf',
#  '2012_HuCaoHongMS.pdf',
#  '2011_LiuHongOR.pdf',
#  '2011_HongYangZhangOR.pdf',
# ...

# %%
md_text = """
---
title: "paper_name"
authors:
- paper_author
# authors_notes: Equal Contributions
date:
doi: ""

# location: Wowchemy HQ
# address:
#   street: 450 Serra Mall
#   city: Stanford
#   region: CA
#   postcode: '94305'
#   country: United States

# Talk start and end times.
#   End time can optionally be hidden by prefixing the line with `#`.
date: "#"
date_end: "#"
all_day: true

# Schedule page publish date (NOT publication's date).
publishDate: "pub_year-01-01T00:00:00Z"

# Publication type.
# Legend: 0 = Uncategorized; 1 = Conference paper; 2 = Journal article;
# 3 = Preprint / Working Paper; 4 = Report; 5 = Book; 6 = Book section;
# 7 = Thesis; 8 = Patent
publication_types: ["2"]

# Publication name and optional abbreviated publication name.
publication: "paper_pub"
publication_short: "paper_pub"

abstract: 

# Summary. An optional shortened abstract.
summary:


featured: false

links:
# - name: Preprint
#   url: https://www.researchgate.net/publication/351599800_Option_pricing_by_stochastic_differential_equations_A_simulation_optimization_approach
url_pdf: "/uploads/papers/journals/file_name"
url_code: ''
url_dataset: ''
url_poster: ''
url_project: ''
url_slides: ''
url_source: ''
url_video: ""


# Featured image
# To use, add an image named `featured.jpg/png` to your page's folder.
# image:
#   caption: 'Image credit: [**Unsplash**](https://unsplash.com/photos/pLCdAaMFLTE)'
#   focal_point: ""
#   preview_only: false

# Associated Projects (optional).
#   Associate this publication with one or more of your projects.
#   Simply enter your project's folder or file name without extension.
#   E.g. `internal-project` references `content/project/internal-project/index.md`.
#   Otherwise, set `projects: []`.
projects:
- 
tags:
- 

# Slides (optional).
#   Associate this publication with Markdown slides.
#   Simply enter your slide deck's filename without extension.
#   E.g. `slides: "example"` references `content/slides/example/index.md`.
#   Otherwise, set `slides: ""`.
slides:
---
"""

# %%
for idx, file in enumerate(good_list):
    ref = refs[idx]
    
    last = ref.split(".")[-1]

    paper_pub = ref.split(".")[-2][1:]

    paper_name = ref.split(".")[-3][1:]

    paper_year = ref.split(".")[-4][1:]

    def name_combine(seg_list):
        string=""
        for name in seg_list:
            string = string + name + "."
        return string[:-1]
    authors = name_combine(ref.split(".")[:-4])

    print(authors)
    print(paper_pub)
    print(paper_name)
    print("\n")
    
    year = file.split(".")[0][:4]
    name = file.split(".")[0]
    print(file, year)
    print("\n")
    new_text = copy.copy(md_text)
    new_text = new_text.replace("pub_year", year)
    new_text =  new_text.replace("file_name", file)
    new_text =  new_text.replace("paper_pub", paper_pub)
    new_text =  new_text.replace("paper_name", paper_name)
    new_text =  new_text.replace("paper_author", authors)
    
    with open(name+".md", "w") as f:
        f.write(new_text)
# 已经成功修改了名字
# Out:
# Zhong, Y. and L. J. Hong
# Operations Research, 70:432-453
# Knockout-tournament procedures for large-scale ranking and selection in parallel computing environments
#
#
# 2022_ZhongHongOR.pdf 2022
#
#
# Zhang, Y., J. Zhang, J. Zhang, J. Wang, K. Lu and L. J. Hong
# ACM Transactions on Intelligent Systems and Technology, 13(3):1-27
# Integrating Algorithmic Sampling-Based Motion Planning with Learning in Autonomous Driving
#
#
# 2022_ZhangZhangZhangWangLuHongTIST.pdf 2022
#
#
# Jiang, X., B. L. Nelson, and L. J. Hong
# IISE Transactions, 54:122-133
# Meaningful sensitivities: A new family of simulation sensitivity measures
#
#
# 2022_JiangNelsonHongIISE.pdf 2022
#
#
# Hong, L. J., W. Fan, and J. Luo
# Frontier of Engineering Management, 8:321-343
# Review on ranking and selection: A new perspective
#
#
# 2021_HongFanLuoFEM.pdf 2021
#
#
# Hong, L. J. and X. Zhang
# INFORMS TutORials in Operations Research, 287-311
# Surrogate-based simulation optimization
#
#
# ...

# %%
# 校对顺序

refs = ["Zhong, Y. and L. J. Hong. 2022. Knockout-tournament procedures for large-scale ranking and selection in parallel computing environments. Operations Research, 70:432-453.",

"Zhang, Y., J. Zhang, J. Zhang, J. Wang, K. Lu and L. J. Hong. 2022. Integrating Algorithmic Sampling-Based Motion Planning with Learning in Autonomous Driving. ACM Transactions on Intelligent Systems and Technology, 13(3):1-27.",

"Jiang, X., B. L. Nelson, and L. J. Hong. 2022. Meaningful sensitivities: A new family of simulation sensitivity measures. IISE Transactions, 54:122-133.",

"Hong, L. J., W. Fan, and J. Luo. 2021. Review on ranking and selection: A new perspective. Frontier of Engineering Management, 8:321-343.",

"Hong, L. J. and X. Zhang. 2021. Surrogate-based simulation optimization. INFORMS TutORials in Operations Research, 287-311.",

"Shen, H., L. J. Hong, and X. Zhang. 2021. Ranking and selection with covariates for personalized decision making. INFORMS Journal on Computing, 33:1500-1519.",

"Zhong, Y., L. J. Hong, and G. Liu. 2021. Earning and learning with varying cost. Production and Operations Management, 30:2379-2394.",

"Hong, L. J., Z. Huang and H. Lam. 2021. Learning-based robust optimization procedures and statistical guarantee. Management Science, 67:3321-3984.",

"Fan, W., L. J. Hong, and X. Zhang. 2020. Distributionally robust selection of the best. Management Science, 66:190-208.",

"Jiang, G., L. J. Hong, and B. L. Nelson. 2020. Online risk monitoring using offline simulation. INFORMS Journal on Computing, 32:356-375.",

"Hong, L. J., C. Li, and J. Luo. 2020. Technical note: Finite‐time regret analysis of Kiefer‐Wolfowitz stochastic approximation algorithm and nonparametric multi‐product dynamic pricing with unknown demand. Naval Research Logistics, 67:368-379.",

"Hong, L. J. and G. Jiang. 2019. Offline simulation online application: A new framework of simulation-based decision making. Asia-Pacific Journal of Operational Research, 36:1940015.",
 
"Yun, X., L. J. Hong, G. Jiang, and S. Wang. 2019. On gamma estimation via matrix kriging. Naval Research Logistics, 66:393-410.",

"Fang, J. and L. J. Hong. 2018. A simulation-based estimation method for bias reduction. IISE Transactions, 50:14-26.",

"Shen, H., L. J. Hong, and X. Zhang. 2018. Enhancing stochastic kriging for queueing simulation with stylized models. IISE Transactions, 50:943–958.",

"Hong, L. J. and G. Jiang. 2017. Gradient and Hessian of joint probability functions with applications on chance constrained programs. Journal of Operations Research Society of China, 5:431-455.",

"Hong, L. J., S. Juneja, and G. Liu. 2017. Kernel smoothing for nested estimation with application to portfolio risk measurement. Operations Research, 65:657-673.",

"Fan, W., L. J. Hong, and B. L. Nelson. 2016. Indifference-zone-free selection of the best. Operations Research, 64:1499-1514.",

"Hong, L. J., X. Xu, and S. H. Zhang. 2015. Capacity reservation for time-sensitive service providers: An application in seaport management. European Journal of Operational Research, 245:470-479.",

"Luo, J., L. J. Hong, B. L. Nelson, and Y. Wu. 2015. Fully sequential procedures for large-scale ranking-and-selection problems in parallel computing environments. Operations Research, 63:1177-1194.",

"Hong, L. J., J. Luo, and B. L. Nelson. 2015. Chance constrained selection of the best. INFORMS Journal on Computing, 27:317-334.",

"Hong, L. J., S. Juneja, and J. Luo. 2014. Estimating sensitivities of portfolio credit risk using Monte Carlo. INFORMS Journal on Computing, 26:848-856. ",

"Hong, L. J. Z. Hu, and G. Liu. 2014. Monte Carlo methods for value-at-risk and conditional value-at-risk: A review. ACM Transactions on Modeling and Computer Simulation, 24:22/1-22/37.",

"Sun, L., L. J. Hong, and Z. Hu. 2014. Balancing exploitation and exploration in discrete optimization via simulation through a Gaussian process-based search. Operations Research, 62:1416-1438.",

"Hong, L. J., Z. Hu, and L. Zhang. 2014. Conditional value-at-risk approximation to value-at-risk constrained programs: A remedy via Monte Carlo. INFORMS Journal on Computing, 26:385-400. ",

"Chang, K.-H., L. J. Hong, and H. Wan. 2013. Stochastic trust-region response-surface method (STRONG) – A new response surface framework for simulation optimization. INFORMS Journal on Computing, 25:230-243. ",

"Xu, J., B. L. Nelson, and L. J. Hong. 2013. An adaptive hyperbox algorithm for high-dimensional discrete optimization via simulation problems. INFORMS Journal on Computing, 25:133-146. ",

"Hu, Z., L. J. Hong, and L. Zhang. 2013. A smooth Monte Carlo approximation to joint chance-constrained programs. IIE Transactions, 45:716-735. ",

"Zhang, J., L. J. Hong, and R. Q. Zhang. 2012. Fighting strategies in a market with counterfeits. Annals of Operations Research, 192:49-66. ",

"Hu, Z., Cao, J., and L. J. Hong. 2012. Robust simulation of global warming policies using the DICE model. Management Science, 58:2190-2206. ",

"Liu, G. and L. J. Hong. 2011. Kernel estimation of the Greeks of financial options. Operations Research, 59:96-108. ",

"Hong, L. J., Y. Yang, and L. Zhang. 2011. Sequential convex approximations to joint chance constrained programs: A Monte Carlo approach. Operations Research, 59:617-630.",

"Hong, L. J., B. L. Nelson, and J. Xu. 2010. Speeding up COMPASS for high-dimensional discrete optimization via simulation. Operations Research Letters, 38:550-555. ",

"Xu, J., B. L. Nelson and L. J. Hong. 2010. Industrial Strength COMPASS: A comprehensive algorithm and software for optimization via simulation. ACM Transactions on Modeling and Computer Simulation, 20: 3/1-3/29. ",

"Sun, L. and L. J. Hong. 2010. Asymptotic representations for importance-sampling estimators of value-at-risk and conditional value-at-risk. Operations Research Letters, 38:246-251. ",

"Hong, L. J. and G. Liu. 2010. Pathwise estimation of probability sensitivities through terminating and steady-state simulations. Operations Research, 58:357-370. ",

"Hong, L. J. 2009. Estimating quantile sensitivities. Operations Research, 57: 118-130. ",
      
"Fu, M. C., L. J. Hong and J. Q. Hu. 2009. Conditional Monte Carlo estimation of quantile sensitivities. Management Science, 55: 2019-2027.",

"Liu, G. and L. J. Hong. 2009. Revisit of stochastic mesh method for pricing American options. Operations Research Letters, 37:411-414. ",

"Liu, G and L. J. Hong. 2009. Kernel estimation of quantile sensitivities. Naval Research Logistics, 56: 511-525. ",

"Hong, L. J. and G. Liu. 2009. Simulating sensitivities of conditional value-at-risk. Management Science, 55: 281-293. ",
        
"Hong, L. J. and B. L. Nelson. 2007. Selecting the best system when systems are revealed sequentially. IIE Transactions, 39:723-734. ",

"Hong, L. J. and B. L. Nelson. 2007. A framework of locally convergent random search algorithms for discrete optimization via simulation. ACM Transactions on Modeling and Computer Simulation, 17: 19/1-19/22.",

"Pichitlamken, J., B. L. Nelson, and L. J. Hong. 2006. A sequential procedure for neighborhood selection-of-the-best in optimization via simulation. European Journal of Operational Research, 173:283-298. ",

"Hong, L. J. 2006. Fully sequential indifference-zone selection procedures with variance dependent sampling. Naval Research Logistics, 53:464-476.",

"Hong, L. J. and B. L. Nelson. 2006. Discrete optimization via simulation using COMPASS. Operations Research, 54:115-129.",

"Hong, L. J. and B. L. Nelson. 2005. The tradeoff between sampling and switching: New sequential procedures for indifference-zone selection.  IIE Transactions, 37:623-634."]

# %%
ref = refs[0]

# %%
ref
# Out:
# 'Zhong, Y. and L. J. Hong. 2022. Knockout-tournament procedures for large-scale ranking and selection in parallel computing environments. Operations Research, 70:432-453.'

# %%
for ref in refs:
    
    last = ref.split(".")[-1]

    paper_pub = ref.split(".")[-2][1:]

    paper_name = ref.split(".")[-3][1:]

    paper_year = ref.split(".")[-4][1:]

    def name_combine(seg_list):
        string=""
        for name in seg_list:
            string = string + name + "."
        return string[:-1]
    authors = name_combine(ref.split(".")[:-4])

    print(authors)
    print(paper_pub)
    print(paper_name)
    print("\n")
# Out:
# Zhong, Y. and L. J. Hong
# Operations Research, 70:432-453
# Knockout-tournament procedures for large-scale ranking and selection in parallel computing environments
#
#
# Zhang, Y., J. Zhang, J. Zhang, J. Wang, K. Lu and L. J. Hong
# ACM Transactions on Intelligent Systems and Technology, 13(3):1-27
# Integrating Algorithmic Sampling-Based Motion Planning with Learning in Autonomous Driving
#
#
# Jiang, X., B. L. Nelson, and L. J. Hong
# IISE Transactions, 54:122-133
# Meaningful sensitivities: A new family of simulation sensitivity measures
#
#
# Hong, L. J., W. Fan, and J. Luo
# Frontier of Engineering Management, 8:321-343
# Review on ranking and selection: A new perspective
#
#
# Hong, L. J. and X. Zhang
# INFORMS TutORials in Operations Research, 287-311
# Surrogate-based simulation optimization
#
#
# Shen, H., L. J. Hong, and X. Zhang
# INFORMS Journal on Computing, 33:1500-1519
# Ranking and selection with covariates for personalized decision making
#
#
# ...

# %%
ref = refs[1]

# %%
ref.split(".")
# Out:
# ['Zhang, Y',
#  ', J',
#  ' Zhang, J',
#  ' Zhang, J',
#  ' Wang, K',
#  ' Lu and L',
#  ' J',
#  ' Hong',
#  ' 2022',
#  ' Integrating Algorithmic Sampling-Based Motion Planning with Learning in Autonomous Driving',
#  ' ACM Transactions on Intelligent Systems and Technology, 13(3):1-27',
#  '']

# %%
last = ref.split(".")[-1]

paper_pub = ref.split(".")[-2][1:]

paper_name = ref.split(".")[-3][1:]

paper_year = ref.split(".")[-4][1:]

def name_combine(seg_list):
    string=""
    for name in seg_list:
        string = string + name + "."
    return string[:-1]
authors = name_combine(ref.split(".")[:-4])

print(authors)
print(paper_pub)
print(paper_name)
# Out:
# Zhang, Y., J. Zhang, J. Zhang, J. Wang, K. Lu and L. J. Hong
# ACM Transactions on Intelligent Systems and Technology, 13(3):1-27
# Integrating Algorithmic Sampling-Based Motion Planning with Learning in Autonomous Driving
